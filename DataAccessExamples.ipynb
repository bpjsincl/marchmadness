# %%
import data_access as da
import pandas as pd
from itertools import combinations

# %%
reload(da)
teams = da.get_teams()
cols = ['year','name']
cols += ['s'+str(i) for i in range(1,31)]
teams_all = pd.DataFrame(teams, columns=cols)

# EXAMPLE OUTPUT FROM TEAMS DF
teams_all[teams_all.name== 'Boise St.'].sort()
# Out:
#       year       name        s1        s2        s3        s4        s5  \
# 131   2010  Boise St.  0.648444 -0.177160  0.283913 -1.498435  0.765696
# 691   2011  Boise St.  0.197292 -1.292773 -0.150037  0.764931  1.164802
# 1036  2012  Boise St.  0.010810 -0.829668  0.092823 -0.070959  1.319159
# 1383  2013  Boise St.  1.083352 -0.709432 -0.382648 -0.514089  0.627335
#
#             s6        s7        s8        s9       s10       s11       s12  \
# 131  -0.022506 -0.417531 -1.105053  1.078148 -0.287224 -0.321432 -0.082902
# 691   2.198750 -1.275042  0.856972  0.298799 -0.034217  0.649623 -0.339402
# 1036 -0.240110 -2.140788  0.422152 -0.120668  0.019392  0.013850 -1.210218
# 1383 -0.073166 -2.315202  1.008082  0.357208  1.740408  1.466867 -1.394898
#
#            s13       s14       s15       s16       s17       s18
# 131   0.525226  0.981459 -0.397605 -1.430757 -0.660526 -0.814330 ...
# 691   0.646215  1.559989  0.828299  0.134551  0.289535  0.067059 ...
# 1036  0.732932  1.524919 -0.664211  0.204240  1.445463  1.178733 ...
# 1383  0.808095  0.048812  0.639167 -0.529842  0.454215  1.067557 ...
#
# [4 rows x 32 columns]

# %%
# Can also get games by matchup
games = pd.DataFrame(da.get_games_matchup('UCLA', 'Washington'))

# CHANGE YEAR HERE:
games_all = pd.DataFrame(da.get_games_year('2010'))
games_all
# Out:
#           team1                   team2  value  year
# 0     Air Force     Charleston Southern    1.3  2010
# 1     Air Force                 Niagara    0.9  2010
# 2     Air Force  North Carolina Central    1.3  2010
# 3     Air Force        Prairie View A&M    2.0  2010
# 4     Air Force      Texas Pan American    0.9  2010
# 5     Air Force                UC Davis    1.3  2010
# 6     Air Force                 Wyoming    2.0  2010
# 7         Akron     Arkansas Pine Bluff    0.5  2010
# 8         Akron                Ball St.    0.9  2010
# 9         Akron           Bowling Green    0.9  2010
# 10        Akron                 Buffalo    1.3  2010
# 11        Akron        Central Michigan    0.5  2010
# 12        Akron                   Drake    0.5  2010
# 13        Akron        Eastern Michigan    0.9  2010
# 14        Akron                  Howard    2.0  2010
# 15        Akron        Illinois Chicago    1.3  2010
# 16        Akron                Miami OH    0.9  2010
# 17        Akron           NC Greensboro    2.0  2010
# 18        Akron                 Niagara    1.3  2010
# 19        Akron       Northern Illinois    1.3  2010
# 20        Akron                    Ohio    0.9  2010
# 21        Akron          St. Francis PA    2.0  2010
# 22        Akron                  Toledo    1.3  2010
# 23        Akron              Valparaiso    2.0  2010
# 24        Akron        Western Michigan    0.5  2010
# 25        Akron                 Wyoming    0.9  2010
# 26      Alabama                Arkansas    0.9  2010
# 27      Alabama                  Auburn    1.3  2010
# 28      Alabama                  Baylor    0.5  2010
# 29      Alabama             Jackson St.    2.0  2010
# 30      Alabama        Louisiana Monroe    2.0  2010
# 31      Alabama           Louisiana St.    2.0  2010
# 32      Alabama                  Mercer    2.0  2010
# 33      Alabama                Michigan    0.5  2010
# 34      Alabama         Mississippi St.    0.9  2010
# 35      Alabama           North Florida    2.0  2010
# 36      Alabama              Providence    0.9  2010
# 37      Alabama                 Samford    2.0  2010
# 38      Alabama          South Carolina    0.9  2010
# 39      Alabama           Tennessee St.    1.3  2010
# 40      Alabama                  Toledo    2.0  2010
# 41  Alabama A&M              Alcorn St.    1.3  2010
# 42  Alabama A&M               Grambling    2.0  2010
# 43  Alabama A&M  Mississippi Valley St.    0.9  2010
# 44  Alabama A&M        Prairie View A&M    0.9  2010
# 45  Alabama A&M                Southern    1.3  2010
# 46  Alabama St.             Alabama A&M    1.3  2010
# 47  Alabama St.              Alcorn St.    2.0  2010
# 48  Alabama St.     Arkansas Pine Bluff    0.5  2010
# 49  Alabama St.               Grambling    2.0  2010
# 50  Alabama St.        Prairie View A&M    0.9  2010
# 51  Alabama St.                Southern    2.0  2010
# 52  Alabama St.          Texas Southern    0.9  2010
# 53       Albany              Alcorn St.    2.0  2010
# 54       Albany                American    0.5  2010
# 55       Albany     MD Baltimore County    1.3  2010
# 56       Albany            Pennsylvania    2.0  2010
# 57       Albany           Robert Morris    0.9  2010
# 58       Albany                    Yale    2.0  2010
# 59   Alcorn St.  Mississippi Valley St.    0.5  2010
#             ...                     ...    ...   ...
#
# [4414 rows x 4 columns]

# %%
# This merges the data together to create the vector to pass into the learning algos.
def make_features(games, teams, team_a, team_b, value):
    fts = pd.merge(
    pd.merge(games, 
             teams, 
             left_on=(team_a, 'year'), 
             right_on=('name', 'year'), 
             how='left'), 
                    teams, 
                    left_on=(team_b, 'year'), 
                    right_on=('name', 'year'), 
                    how='left',
                    suffixes=('_1','_2'))
    fts['value'] = value
    fts = fts[(fts.name_1.notnull()) & (fts.name_2.notnull())]
    return fts
    
features_1 = make_features(games_all, teams_all, 'team1', 'team2', 1)
features_2 = make_features(games_all, teams_all, 'team2', 'team1', 0)

# combine remove unwanted columns
features_total = pd.concat([features_1, features_2])
features_total.drop(['team1','team2','year','name_1','name_2'], inplace=True, axis=1)

# move value to end
cols = features_total.columns.tolist()
cols = cols[1:] + cols[:1]
features_total = features_total[cols]
features_total.iloc[0].tolist()
# Out:
# [0.42197865262170081,
#  0.88556499332384342,
#  -2.4421811865725096,
#  -0.62533100972799671,
#  1.5154740732650658,
#  -0.16955080102998724,
#  -0.40932775482717643,
#  0.28836784831899409,
#  1.429073106557313,
#  -0.98270077222459251,
#  -1.36262796981016,
#  -1.2195342841446912,
#  2.1092838601674551,
#  0.1376593652976309,
#  -0.2259647533394904,
#  0.7593067504280725,
#  1.3093605667793096,
#  2.9388893731969579,
#  1.4877454287721483,
#  1.4688633429573454,
#  -0.95306054808719076,
#  0.17488754888653887,
#  -1.6780438290544968,
#  -2.4819167144451422,
#  -2.8023186418641779,
#  -1.0082939126823411,
#  -0.69599485519455118,
#  0.96284562288562991,
#  0.56771388943500123,
#  -0.85086974852828046,
#  -0.61841033053550609,
#  0.61442196610135313,
#  0.40149431029307248,
#  -1.7085626858171685,
#  0.20056056231287364,
#  0.084993240542349122,
#  0.82951266329574658,
#  0.094427642260362349,
#  -0.9041787396777603,
#  0.15797923970690667,
#  -0.70214445561402794,
#  0.59620024890833134,
#  0.58160996258405451,
#  -0.50066364742109004,
#  -0.99685316805979174,
#  -1.0042136980275602,
#  -0.33864546050642735,
#  -0.27061838391934934,
#  -2.0780030595072736,
#  0.2330526021263557,
#  1.0661090894771599,
#  0.89054205516945828,
#  -0.28446423503493057,
#  -0.45185900296103382,
#  -0.97822641456206305,
#  -0.75551539068680329,
#  -1.1209229714204265,
#  0.2258613804083924,
#  0.8444917771894549,
#  -1.214211937970453,
#  1.0]

# %%
# given two teams and season, create the feature vector for testing
def make_features_matchup(teams, team_a, team_b, year):
    t_A_fts = teams[(teams.name==team_a) & (teams.year == year)]
    t_B_fts = teams[(teams.name==team_b) & (teams.year == year)]
    
    fts = pd.merge(t_A_fts, t_B_fts, how='inner', on='year', suffixes=('_1','_2'))
    fts.drop(['name_1','name_2','year'], inplace=True, axis=1)
    return fts

fs = make_features_matchup(teams_all, 'Air Force', 'Charleston Southern', 2010)
fs
# Out:
#        s1_1      s2_1      s3_1      s4_1      s5_1      s6_1      s7_1  \
# 0  0.421979  0.885565 -2.442181 -0.625331  1.515474 -0.169551 -0.409328
#
#        s8_1      s9_1     s10_1     s11_1     s12_1     s13_1     s14_1  \
# 0  0.288368  1.429073 -0.982701 -1.362628 -1.219534  2.109284  0.137659
#
#       s15_1     s16_1     s17_1     s18_1     s19_1     s20_1
# 0 -0.225965  0.759307  1.309361  2.938889  1.487745  1.468863 ...
#
# [1 rows x 60 columns]

# %%
kag_teams = pd.read_csv('data_files/teams.csv')
kag_seeds = pd.read_csv('data_files/tourney_seeds.csv')
dd = pd.read_csv('data_files/tourney_results.csv')
win_ts = dd.ix[dd.season=='R', ['wteam', 'lteam']]

# %%
# CREATES ALL THE MATCHUPS FOR A GIVEN SEASON:
# FORMAT: [T_1_features, T_2_features]
# needs some kaggle and some leswing data
mapper = [('Nevada Las Vegas', 'UNLV'),
              ('North Carolina St.' ,'NC State'),
              ('Virginia Commonwealth','VA Commonwealth'),
              ('San Diego St.', 'San Diego St'),
              ('South Dakota St.','S Dakota St'),
              ('Northwestern St.', 'Northwestern LA'),
              ('Florida Gulf Coast','FL Gulf Coast'),
              ('Western Kentucky','W Kentucky'),
              ('Michigan St.','Michigan St'),
              ('St. Louis','St Louis'),
              ('Oklahoma St.','Oklahoma St'),
              ('Colorado St.', 'Colorado St'),
              ('Middle Tennessee', 'Middle Tenn St'),
              ("St. Mary's", "St Mary's CA"),
              ('New Mexico St.', 'New Mexico St'),
              ('Albany', 'Albany NY'),
              ('North Carolina A&T', 'NC A&T'),
              ('Ohio St.','Ohio St'),
              ('Kansas St.','Kansas St'),
              ('Wichita St.','Wichita St'),
              ('Iowa St.', 'Iowa St'),
              ('Boise St.','Boise St'),
              ('Southern','Southern Univ')]

def modify_teams(teams, mapper):
        for team in mapper:
            teams.ix[teams.name==team[0],'name'] = team[1]

        return teams

def create_tournament(teams, kag_teams, kag_seeds, year, season):
    cols = ['name']
    cols += ['s'+str(i) for i in range(1,31)]

    teams_combined = pd.merge(pd.merge(kag_seeds[kag_seeds.season==season].sort(columns='team'), 
                                       kag_teams, 
                                       left_on='team', 
                                       right_on='id', 
                                       how='left'),
                           teams[teams.year==year], 
                           left_on='name', 
                           right_on='name', 
                           how='left',
                           suffixes=('_1', '_2'))
    
    team_tuples = [tuple(x) for x in teams_combined[cols].values]
    tournament = [(i[1:] + j[1:]) for i, j in combinations(team_tuples, 2)]
    teams = [(i[0], j[0]) for i,j in combinations(team_tuples,2)]
    
    return tournament, teams

# %%
teams_mod = modify_teams(teams_all, mapper)
tournament, t_teams = create_tournament(teams_mod, kag_teams, kag_seeds, 2013, 'R')
len(tournament)
# Out:
# 2278

# %%
from sklearn import metrics

# %%
metrics.log_loss([1,0,0,1],[(0.2, 0.8),(1.0,0.0),(0.4,0.6),(0.1,0.9)])
# Out:
# 0.31119869971154801

# %%
dd = pd.read_csv('data_files/tourney_results.csv')
wt = dd.ix[dd.season=='R', ['wteam', 'lteam']]
# wt
results = pd.merge(pd.merge(wt, 
                            kag_teams, 
                            left_on='wteam', 
                            right_on='id',
                            how='left'),
                   kag_teams, 
                   left_on='lteam',
                   right_on='id', 
                   suffixes=('_1','_2'))
results.drop(['id_1','id_2'], inplace=True, axis=1)

def checker(r):
    if r[0] > r[1]: return 1
    else: return 0

results['result'] = [checker(r) for r in results.values]
results
# Out:
#     wteam  lteam           name_1           name_2  result
# 0     693    645           NC A&T          Liberty       1
# 1     781    672     St Mary's CA   Middle Tenn St       1
# 2     635    648    James Madison      Long Island       0
# 3     641    526         La Salle         Boise St       1
# 4     641    637         La Salle        Kansas St       1
# 5     641    674         La Salle      Mississippi       0
# 6     511    522          Arizona          Belmont       0
# 7     511    612          Arizona          Harvard       0
# 8     535    533           Butler         Bucknell       1
# 9     539    817       California             UNLV       0
# 10    557    676      Colorado St         Missouri       0
# 11    607    773          Gonzaga    Southern Univ       0
# 12    612    701          Harvard       New Mexico       0
# 13    651    693       Louisville           NC A&T       0
# 14    651    557       Louisville      Colorado St       1
# 15    651    725       Louisville           Oregon       0
# 16    651    577       Louisville             Duke       1
# 17    651    846       Louisville       Wichita St       0
# 18    651    670       Louisville         Michigan       0
# 19    660    568        Marquette         Davidson       1
# 20    660    535        Marquette           Butler       1
# 21    660    668        Marquette         Miami FL       0
# 22    666    781          Memphis     St Mary's CA       0
# 23    670    748         Michigan      S Dakota St       0
# 24    670    825         Michigan  VA Commonwealth       0
# 25    670    636         Michigan           Kansas       1
# 26    670    592         Michigan          Florida       1
# 27    670    786         Michigan         Syracuse       0
# 28    671    826      Michigan St       Valparaiso       0
# 29    671    666      Michigan St          Memphis       1
# 30    725    722           Oregon      Oklahoma St       1
# 31    725    780           Oregon         St Louis       0
# 32    780    702         St Louis    New Mexico St       1
# 33    786    680         Syracuse          Montana       1
# 34    786    539         Syracuse       California       1
# 35    786    625         Syracuse          Indiana       1
# 36    786    660         Syracuse        Marquette       1
# 37    825    503  VA Commonwealth            Akron       1
# 38    846    731       Wichita St       Pittsburgh       1
# 39    846    607       Wichita St          Gonzaga       1
# 40    846    641       Wichita St         La Salle       1
# 41    846    720       Wichita St          Ohio St       1
# 42    562    549        Creighton       Cincinnati       1
# 43    577    507             Duke        Albany NY       1
# 44    577    562             Duke        Creighton       1
# 45    577    671             Duke      Michigan St       0
# 46    591    603    FL Gulf Coast       Georgetown       0
# 47    591    754    FL Gulf Coast     San Diego St       0
# 48    592    716          Florida  Northwestern LA       0
# 49    592    673          Florida        Minnesota       0
# 50    592    591          Florida    FL Gulf Coast       1
# 51    623    556         Illinois         Colorado       1
# 52    625    635          Indiana    James Madison       0
# 53    625    789          Indiana           Temple       0
# 54    629    717          Iowa St       Notre Dame       0
# 55    636    835           Kansas       W Kentucky       0
# 56    636    708           Kansas   North Carolina       0
# 57    668    727         Miami FL          Pacific       0
# 58    668    623         Miami FL         Illinois       1
# 59    673    810        Minnesota             UCLA       0
#       ...    ...              ...              ...     ...
#
# [67 rows x 5 columns]

# %%
# t_teams
# results.values
5/10
# Out:
# 0
